# %%
import pandas as pd

# %%
df = pd.read_csv('base_pichau.csv')
df
# Out:
#                                               produto       precos  \
# 0   Computador Gamer Pichau, AMD Ryzen 5 2400G, 16...  R$ 1.520,00
# 1   Computador Gamer Pichau, AMD Ryzen 5 2400G, 16...  R$ 1.450,00
# 2   Computador Gamer Pichau, AMD Ryzen 5 2400G, 8G...  R$ 1.299,99
# 3   Computador Gamer Pichau, AMD Ryzen 5 2400G, 8G...  R$ 1.259,99
# 4   PC Gamer Pichau Sigyn III, Intel i5-10400F, Ge...  R$ 2.648,31
# 5   PC Gamer Mancer, Intel i3-14100, UHD 730, 16GB...  R$ 2.489,96
# 6   PC Gamer Pichau, Intel i3-12100, UHD 730, 16GB...  R$ 2.199,97
# 7   PC Gamer Pichau Crisipo, AMD Ryzen 5 5600X, Ra...  R$ 4.872,55
# 8   PC Gamer Pichau Creteu, AMD Ryzen 5 5600X, GeF...  R$ 6.634,08
# 9   PC Gamer Pichau, Intel i3-12100F, GeForce GTX ...  R$ 2.459,98
# 10  PC Gamer Pichau Afrodite, Intel i5-13400F, Rad...  R$ 3.799,86
# 11  PC Gamer Completo Pichau Cicreu VI, AMD Ryzen ...  R$ 2.589,99
# 12  PC Gamer Completo Pichau Cicreu V, AMD Ryzen 3...  R$ 2.089,98
# ...

# %%
df['valor parcelado']=df['valor parcelado'].str.replace('em até', ' ').str.replace('\nsem juros no cartão', ' ')
df
# Out:
#                                               produto       precos  \
# 0   Computador Gamer Pichau, AMD Ryzen 5 2400G, 16...  R$ 1.520,00
# 1   Computador Gamer Pichau, AMD Ryzen 5 2400G, 16...  R$ 1.450,00
# 2   Computador Gamer Pichau, AMD Ryzen 5 2400G, 8G...  R$ 1.299,99
# 3   Computador Gamer Pichau, AMD Ryzen 5 2400G, 8G...  R$ 1.259,99
# 4   PC Gamer Pichau Sigyn III, Intel i5-10400F, Ge...  R$ 2.648,31
# 5   PC Gamer Mancer, Intel i3-14100, UHD 730, 16GB...  R$ 2.489,96
# 6   PC Gamer Pichau, Intel i3-12100, UHD 730, 16GB...  R$ 2.199,97
# 7   PC Gamer Pichau Crisipo, AMD Ryzen 5 5600X, Ra...  R$ 4.872,55
# 8   PC Gamer Pichau Creteu, AMD Ryzen 5 5600X, GeF...  R$ 6.634,08
# 9   PC Gamer Pichau, Intel i3-12100F, GeForce GTX ...  R$ 2.459,98
# 10  PC Gamer Pichau Afrodite, Intel i5-13400F, Rad...  R$ 3.799,86
# 11  PC Gamer Completo Pichau Cicreu VI, AMD Ryzen ...  R$ 2.589,99
# 12  PC Gamer Completo Pichau Cicreu V, AMD Ryzen 3...  R$ 2.089,98
# ...

# %%
df
# Out:
#                                               produto       precos  \
# 0   Computador Gamer Pichau, AMD Ryzen 5 2400G, 16...  R$ 1.520,00
# 1   Computador Gamer Pichau, AMD Ryzen 5 2400G, 16...  R$ 1.450,00
# 2   Computador Gamer Pichau, AMD Ryzen 5 2400G, 8G...  R$ 1.299,99
# 3   Computador Gamer Pichau, AMD Ryzen 5 2400G, 8G...  R$ 1.259,99
# 4   PC Gamer Pichau Sigyn III, Intel i5-10400F, Ge...  R$ 2.648,31
# 5   PC Gamer Mancer, Intel i3-14100, UHD 730, 16GB...  R$ 2.489,96
# 6   PC Gamer Pichau, Intel i3-12100, UHD 730, 16GB...  R$ 2.199,97
# 7   PC Gamer Pichau Crisipo, AMD Ryzen 5 5600X, Ra...  R$ 4.872,55
# 8   PC Gamer Pichau Creteu, AMD Ryzen 5 5600X, GeF...  R$ 6.634,08
# 9   PC Gamer Pichau, Intel i3-12100F, GeForce GTX ...  R$ 2.459,98
# 10  PC Gamer Pichau Afrodite, Intel i5-13400F, Rad...  R$ 3.799,86
# 11  PC Gamer Completo Pichau Cicreu VI, AMD Ryzen ...  R$ 2.589,99
# 12  PC Gamer Completo Pichau Cicreu V, AMD Ryzen 3...  R$ 2.089,98
# ...

# %%
novas_colunas.columns = ['nome do produto', 'processador', 'memória ram', 'armazenamento', 'placa de video']
novas_colunas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 novas_colunas.columns = ['nome do produto', 'processador', 'memória ram', 'armazenamento', 'placa de video']
#       2 novas_colunas
#
# NameError: name 'novas_colunas' is not defined

# %%
df = pd.concat([df, novas_colunas], axis=1)
df
# Out:
#                                               produto       precos  \
# 0   Computador Gamer Pichau, AMD Ryzen 5 2400G, 16...  R$ 1.520,00
# 1   Computador Gamer Pichau, AMD Ryzen 5 2400G, 16...  R$ 1.450,00
# 2   Computador Gamer Pichau, AMD Ryzen 5 2400G, 8G...  R$ 1.299,99
# 3   Computador Gamer Pichau, AMD Ryzen 5 2400G, 8G...  R$ 1.259,99
# 4   PC Gamer Pichau Sigyn III, Intel i5-10400F, Ge...  R$ 2.648,31
# 5   PC Gamer Mancer, Intel i3-14100, UHD 730, 16GB...  R$ 2.489,96
# 6   PC Gamer Pichau, Intel i3-12100, UHD 730, 16GB...  R$ 2.199,97
# 7   PC Gamer Pichau Crisipo, AMD Ryzen 5 5600X, Ra...  R$ 4.872,55
# 8   PC Gamer Pichau Creteu, AMD Ryzen 5 5600X, GeF...  R$ 6.634,08
# 9   PC Gamer Pichau, Intel i3-12100F, GeForce GTX ...  R$ 2.459,98
# 10  PC Gamer Pichau Afrodite, Intel i5-13400F, Rad...  R$ 3.799,86
# 11  PC Gamer Completo Pichau Cicreu VI, AMD Ryzen ...  R$ 2.589,99
# 12  PC Gamer Completo Pichau Cicreu V, AMD Ryzen 3...  R$ 2.089,98
# ...

# %%
df = df.drop(['produto'], axis=1)
df
# Out:
#          precos                 desconto      valor parcelado  \
# 0   R$ 1.520,00  no PIX com 15% desconto    12x de R$ 149,02
# 1   R$ 1.450,00  no PIX com 15% desconto    12x de R$ 142,16
# 2   R$ 1.299,99  no PIX com 15% desconto    12x de R$ 127,45
# 3   R$ 1.259,99  no PIX com 15% desconto    12x de R$ 123,53
# 4   R$ 2.648,31  no PIX com 15% desconto    12x de R$ 259,64
# 5   R$ 2.489,96  no PIX com 15% desconto    12x de R$ 244,11
# 6   R$ 2.199,97  no PIX com 15% desconto    12x de R$ 215,68
# 7   R$ 4.872,55  no PIX com 15% desconto    12x de R$ 477,70
# 8   R$ 6.634,08  no PIX com 15% desconto    12x de R$ 650,40
# 9   R$ 2.459,98  no PIX com 15% desconto    12x de R$ 241,17
# 10  R$ 3.799,86  no PIX com 15% desconto    12x de R$ 372,54
# 11  R$ 2.589,99  no PIX com 15% desconto    12x de R$ 253,92
# 12  R$ 2.089,98  no PIX com 15% desconto    12x de R$ 204,90
# 13  R$ 2.889,98  no PIX com 15% desconto    12x de R$ 283,33
# ...

# %%
# Nova ordem das colunas
nova_ordem = [
    'nome do produto', 
    'processador', 
    'memória ram', 
    'armazenamento', 
    'placa de video', 
    'precos', 
    'desconto', 
    'valor parcelado'
]

# Reordenando as colunas
df = df[nova_ordem]

# Exibindo o DataFrame reordenado
print(df)
# Out:
#                         nome do produto          processador  \
# 0               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 1               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 2               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 3               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 4             PC Gamer Pichau Sigyn III      Intel i5-10400F
# 5                       PC Gamer Mancer       Intel i3-14100
# 6                       PC Gamer Pichau       Intel i3-12100
# 7               PC Gamer Pichau Crisipo    AMD Ryzen 5 5600X
# 8                PC Gamer Pichau Creteu    AMD Ryzen 5 5600X
# 9                       PC Gamer Pichau      Intel i3-12100F
# 10             PC Gamer Pichau Afrodite      Intel i5-13400F
# 11   PC Gamer Completo Pichau Cicreu VI   AMD Ryzen 3 4350GE
# 12    PC Gamer Completo Pichau Cicreu V   AMD Ryzen 3 4350GE
# 13   PC Gamer Completo Mancer Feácio VI    AMD Ryzen 3 5300G
# ...

# %%
# Mudando a linha 4
df.loc[4, 'memória ram'], df.loc[4, 'placa de video'] = df.loc[4, 'placa de video'], df.loc[4, 'memória ram']
df
# Out:
#                         nome do produto          processador memória ram  \
# 0               Computador Gamer Pichau    AMD Ryzen 5 2400G   16GB DDR4
# 1               Computador Gamer Pichau    AMD Ryzen 5 2400G   16GB DDR4
# 2               Computador Gamer Pichau    AMD Ryzen 5 2400G    8GB DDR4
# 3               Computador Gamer Pichau    AMD Ryzen 5 2400G    8GB DDR4
# 4             PC Gamer Pichau Sigyn III      Intel i5-10400F   16GB DDR4
# 5                       PC Gamer Mancer       Intel i3-14100     UHD 730
# 6                       PC Gamer Pichau       Intel i3-12100   16GB DDR4
# 7               PC Gamer Pichau Crisipo    AMD Ryzen 5 5600X   16GB DDR4
# 8                PC Gamer Pichau Creteu    AMD Ryzen 5 5600X   16GB DDR4
# 9                       PC Gamer Pichau      Intel i3-12100F    8GB DDR4
# 10             PC Gamer Pichau Afrodite      Intel i5-13400F   16GB DDR4
# 11   PC Gamer Completo Pichau Cicreu VI   AMD Ryzen 3 4350GE   16GB DDR4
# ...

# %%
# mudando a linha cinco
df.loc[5, 'memória ram'], df.loc[5, 'armazenamento'], df.loc[5,'placa de video'] = df.loc[5,'placa de video'], df.loc[5,'memória ram'], df.loc[5,'armazenamento']
df
# Out:
#                         nome do produto          processador memória ram  \
# 0               Computador Gamer Pichau    AMD Ryzen 5 2400G   16GB DDR4
# 1               Computador Gamer Pichau    AMD Ryzen 5 2400G   16GB DDR4
# 2               Computador Gamer Pichau    AMD Ryzen 5 2400G    8GB DDR4
# 3               Computador Gamer Pichau    AMD Ryzen 5 2400G    8GB DDR4
# 4             PC Gamer Pichau Sigyn III      Intel i5-10400F   16GB DDR4
# 5                       PC Gamer Mancer       Intel i3-14100   16GB DDR4
# 6                       PC Gamer Pichau       Intel i3-12100   16GB DDR4
# 7               PC Gamer Pichau Crisipo    AMD Ryzen 5 5600X   16GB DDR4
# 8                PC Gamer Pichau Creteu    AMD Ryzen 5 5600X   16GB DDR4
# 9                       PC Gamer Pichau      Intel i3-12100F    8GB DDR4
# 10             PC Gamer Pichau Afrodite      Intel i5-13400F   16GB DDR4
# 11   PC Gamer Completo Pichau Cicreu VI   AMD Ryzen 3 4350GE   16GB DDR4
# ...

# %%
# mudando a linha 6 
df.loc[6, 'memória ram'], df.loc[6, 'armazenamento'], df.loc[6, 'placa de video'] = df.loc[6, 'armazenamento'], df.loc[6, 'placa de video'], df.loc[6, 'memória ram']
df
# Out:
#                         nome do produto          processador  \
# 0               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 1               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 2               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 3               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 4             PC Gamer Pichau Sigyn III      Intel i5-10400F
# 5                       PC Gamer Mancer       Intel i3-14100
# 6                       PC Gamer Pichau       Intel i3-12100
# 7               PC Gamer Pichau Crisipo    AMD Ryzen 5 5600X
# 8                PC Gamer Pichau Creteu    AMD Ryzen 5 5600X
# 9                       PC Gamer Pichau      Intel i3-12100F
# 10             PC Gamer Pichau Afrodite      Intel i5-13400F
# 11   PC Gamer Completo Pichau Cicreu VI   AMD Ryzen 3 4350GE
# 12    PC Gamer Completo Pichau Cicreu V   AMD Ryzen 3 4350GE
# 13   PC Gamer Completo Mancer Feácio VI    AMD Ryzen 3 5300G
# ...

# %%
# mudando a linha 7

df.loc[7, 'memória ram'], df.loc[7, 'armazenamento'], df.loc[7, 'placa de video'] = df.loc[7, 'armazenamento'], df.loc[7, 'placa de video'], df.loc[7, 'memória ram']
df
# Out:
#                         nome do produto          processador  \
# 0               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 1               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 2               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 3               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 4             PC Gamer Pichau Sigyn III      Intel i5-10400F
# 5                       PC Gamer Mancer       Intel i3-14100
# 6                       PC Gamer Pichau       Intel i3-12100
# 7               PC Gamer Pichau Crisipo    AMD Ryzen 5 5600X
# 8                PC Gamer Pichau Creteu    AMD Ryzen 5 5600X
# 9                       PC Gamer Pichau      Intel i3-12100F
# 10             PC Gamer Pichau Afrodite      Intel i5-13400F
# 11   PC Gamer Completo Pichau Cicreu VI   AMD Ryzen 3 4350GE
# 12    PC Gamer Completo Pichau Cicreu V   AMD Ryzen 3 4350GE
# 13   PC Gamer Completo Mancer Feácio VI    AMD Ryzen 3 5300G
# ...

# %%
# mudando a linha 8

df.loc[8, 'memória ram'], df.loc[8, 'armazenamento'], df.loc[8, 'placa de video'] = df.loc[8, 'armazenamento'], df.loc[8, 'placa de video'], df.loc[8, 'memória ram']
df
# Out:
#                         nome do produto          processador  \
# 0               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 1               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 2               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 3               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 4             PC Gamer Pichau Sigyn III      Intel i5-10400F
# 5                       PC Gamer Mancer       Intel i3-14100
# 6                       PC Gamer Pichau       Intel i3-12100
# 7               PC Gamer Pichau Crisipo    AMD Ryzen 5 5600X
# 8                PC Gamer Pichau Creteu    AMD Ryzen 5 5600X
# 9                       PC Gamer Pichau      Intel i3-12100F
# 10             PC Gamer Pichau Afrodite      Intel i5-13400F
# 11   PC Gamer Completo Pichau Cicreu VI   AMD Ryzen 3 4350GE
# 12    PC Gamer Completo Pichau Cicreu V   AMD Ryzen 3 4350GE
# 13   PC Gamer Completo Mancer Feácio VI    AMD Ryzen 3 5300G
# ...

# %%
# mudando a linha 9
df.loc[9, 'memória ram'], df.loc[9, 'armazenamento'], df.loc[9, 'placa de video'] = df.loc[9, 'armazenamento'], df.loc[9, 'placa de video'], df.loc[9, 'memória ram']
df
# Out:
#                         nome do produto          processador  \
# 0               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 1               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 2               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 3               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 4             PC Gamer Pichau Sigyn III      Intel i5-10400F
# 5                       PC Gamer Mancer       Intel i3-14100
# 6                       PC Gamer Pichau       Intel i3-12100
# 7               PC Gamer Pichau Crisipo    AMD Ryzen 5 5600X
# 8                PC Gamer Pichau Creteu    AMD Ryzen 5 5600X
# 9                       PC Gamer Pichau      Intel i3-12100F
# 10             PC Gamer Pichau Afrodite      Intel i5-13400F
# 11   PC Gamer Completo Pichau Cicreu VI   AMD Ryzen 3 4350GE
# 12    PC Gamer Completo Pichau Cicreu V   AMD Ryzen 3 4350GE
# 13   PC Gamer Completo Mancer Feácio VI    AMD Ryzen 3 5300G
# ...

# %%
#mundando a linha 10
df.loc[10, 'memória ram'], df.loc[10, 'armazenamento'], df.loc[10, 'placa de video'] = df.loc[10, 'armazenamento'], df.loc[10, 'placa de video'], df.loc[10, 'memória ram']
df
# Out:
#                         nome do produto          processador  \
# 0               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 1               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 2               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 3               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 4             PC Gamer Pichau Sigyn III      Intel i5-10400F
# 5                       PC Gamer Mancer       Intel i3-14100
# 6                       PC Gamer Pichau       Intel i3-12100
# 7               PC Gamer Pichau Crisipo    AMD Ryzen 5 5600X
# 8                PC Gamer Pichau Creteu    AMD Ryzen 5 5600X
# 9                       PC Gamer Pichau      Intel i3-12100F
# 10             PC Gamer Pichau Afrodite      Intel i5-13400F
# 11   PC Gamer Completo Pichau Cicreu VI   AMD Ryzen 3 4350GE
# 12    PC Gamer Completo Pichau Cicreu V   AMD Ryzen 3 4350GE
# 13   PC Gamer Completo Mancer Feácio VI    AMD Ryzen 3 5300G
# ...

# %%
# mudando a linha 16
df.loc[16, 'memória ram'], df.loc[16, 'armazenamento'], df.loc[16, 'placa de video'] = df.loc[16, 'armazenamento'], df.loc[16, 'placa de video'], df.loc[16, 'memória ram']
df
# Out:
#                         nome do produto          processador  \
# 0               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 1               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 2               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 3               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 4             PC Gamer Pichau Sigyn III      Intel i5-10400F
# 5                       PC Gamer Mancer       Intel i3-14100
# 6                       PC Gamer Pichau       Intel i3-12100
# 7               PC Gamer Pichau Crisipo    AMD Ryzen 5 5600X
# 8                PC Gamer Pichau Creteu    AMD Ryzen 5 5600X
# 9                       PC Gamer Pichau      Intel i3-12100F
# 10             PC Gamer Pichau Afrodite      Intel i5-13400F
# 11   PC Gamer Completo Pichau Cicreu VI   AMD Ryzen 3 4350GE
# 12    PC Gamer Completo Pichau Cicreu V   AMD Ryzen 3 4350GE
# 13   PC Gamer Completo Mancer Feácio VI    AMD Ryzen 3 5300G
# ...

# %%
#mudando a linha 20
df.loc[20, 'memória ram'], df.loc[20, 'armazenamento'], df.loc[20, 'placa de video'] = df.loc[20, 'armazenamento'], df.loc[20, 'placa de video'], df.loc[20, 'memória ram']
df
# Out:
#                         nome do produto          processador  \
# 0               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 1               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 2               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 3               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 4             PC Gamer Pichau Sigyn III      Intel i5-10400F
# 5                       PC Gamer Mancer       Intel i3-14100
# 6                       PC Gamer Pichau       Intel i3-12100
# 7               PC Gamer Pichau Crisipo    AMD Ryzen 5 5600X
# 8                PC Gamer Pichau Creteu    AMD Ryzen 5 5600X
# 9                       PC Gamer Pichau      Intel i3-12100F
# 10             PC Gamer Pichau Afrodite      Intel i5-13400F
# 11   PC Gamer Completo Pichau Cicreu VI   AMD Ryzen 3 4350GE
# 12    PC Gamer Completo Pichau Cicreu V   AMD Ryzen 3 4350GE
# 13   PC Gamer Completo Mancer Feácio VI    AMD Ryzen 3 5300G
# ...

# %%
#mudando a linha 22
df.loc[22, 'memória ram'], df.loc[22, 'armazenamento'], df.loc[22, 'placa de video'] = df.loc[22, 'armazenamento'], df.loc[22, 'placa de video'], df.loc[22, 'memória ram']
df
# Out:
#                         nome do produto          processador  \
# 0               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 1               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 2               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 3               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 4             PC Gamer Pichau Sigyn III      Intel i5-10400F
# 5                       PC Gamer Mancer       Intel i3-14100
# 6                       PC Gamer Pichau       Intel i3-12100
# 7               PC Gamer Pichau Crisipo    AMD Ryzen 5 5600X
# 8                PC Gamer Pichau Creteu    AMD Ryzen 5 5600X
# 9                       PC Gamer Pichau      Intel i3-12100F
# 10             PC Gamer Pichau Afrodite      Intel i5-13400F
# 11   PC Gamer Completo Pichau Cicreu VI   AMD Ryzen 3 4350GE
# 12    PC Gamer Completo Pichau Cicreu V   AMD Ryzen 3 4350GE
# 13   PC Gamer Completo Mancer Feácio VI    AMD Ryzen 3 5300G
# ...

# %%
#mudando a linha 23
df.loc[23, 'memória ram'], df.loc[23, 'armazenamento'], df.loc[23, 'placa de video'] = df.loc[23, 'armazenamento'], df.loc[23, 'placa de video'], df.loc[23, 'memória ram']
df
# Out:
#                         nome do produto          processador  \
# 0               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 1               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 2               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 3               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 4             PC Gamer Pichau Sigyn III      Intel i5-10400F
# 5                       PC Gamer Mancer       Intel i3-14100
# 6                       PC Gamer Pichau       Intel i3-12100
# 7               PC Gamer Pichau Crisipo    AMD Ryzen 5 5600X
# 8                PC Gamer Pichau Creteu    AMD Ryzen 5 5600X
# 9                       PC Gamer Pichau      Intel i3-12100F
# 10             PC Gamer Pichau Afrodite      Intel i5-13400F
# 11   PC Gamer Completo Pichau Cicreu VI   AMD Ryzen 3 4350GE
# 12    PC Gamer Completo Pichau Cicreu V   AMD Ryzen 3 4350GE
# 13   PC Gamer Completo Mancer Feácio VI    AMD Ryzen 3 5300G
# ...

# %%
# mudando a linha 27
df.loc[27, 'memória ram'], df.loc[27, 'armazenamento'], df.loc[27, 'placa de video'] = df.loc[27, 'armazenamento'], df.loc[27, 'placa de video'], df.loc[27, 'memória ram']
df
# Out:
#                         nome do produto          processador  \
# 0               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 1               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 2               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 3               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 4             PC Gamer Pichau Sigyn III      Intel i5-10400F
# 5                       PC Gamer Mancer       Intel i3-14100
# 6                       PC Gamer Pichau       Intel i3-12100
# 7               PC Gamer Pichau Crisipo    AMD Ryzen 5 5600X
# 8                PC Gamer Pichau Creteu    AMD Ryzen 5 5600X
# 9                       PC Gamer Pichau      Intel i3-12100F
# 10             PC Gamer Pichau Afrodite      Intel i5-13400F
# 11   PC Gamer Completo Pichau Cicreu VI   AMD Ryzen 3 4350GE
# 12    PC Gamer Completo Pichau Cicreu V   AMD Ryzen 3 4350GE
# 13   PC Gamer Completo Mancer Feácio VI    AMD Ryzen 3 5300G
# ...

# %%
#mudando a linha 28
df.loc[28, 'memória ram'], df.loc[28, 'armazenamento'], df.loc[28, 'placa de video'] = df.loc[28, 'armazenamento'], df.loc[28, 'placa de video'], df.loc[28, 'memória ram']
df
# Out:
#                         nome do produto          processador  \
# 0               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 1               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 2               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 3               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 4             PC Gamer Pichau Sigyn III      Intel i5-10400F
# 5                       PC Gamer Mancer       Intel i3-14100
# 6                       PC Gamer Pichau       Intel i3-12100
# 7               PC Gamer Pichau Crisipo    AMD Ryzen 5 5600X
# 8                PC Gamer Pichau Creteu    AMD Ryzen 5 5600X
# 9                       PC Gamer Pichau      Intel i3-12100F
# 10             PC Gamer Pichau Afrodite      Intel i5-13400F
# 11   PC Gamer Completo Pichau Cicreu VI   AMD Ryzen 3 4350GE
# 12    PC Gamer Completo Pichau Cicreu V   AMD Ryzen 3 4350GE
# 13   PC Gamer Completo Mancer Feácio VI    AMD Ryzen 3 5300G
# ...

# %%
# mudando a linha 33
df.loc[33, 'memória ram'], df.loc[33, 'armazenamento'], df.loc[33, 'placa de video'] = df.loc[33, 'armazenamento'], df.loc[33, 'placa de video'], df.loc[33, 'memória ram']
df
# Out:
#                         nome do produto          processador  \
# 0               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 1               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 2               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 3               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 4             PC Gamer Pichau Sigyn III      Intel i5-10400F
# 5                       PC Gamer Mancer       Intel i3-14100
# 6                       PC Gamer Pichau       Intel i3-12100
# 7               PC Gamer Pichau Crisipo    AMD Ryzen 5 5600X
# 8                PC Gamer Pichau Creteu    AMD Ryzen 5 5600X
# 9                       PC Gamer Pichau      Intel i3-12100F
# 10             PC Gamer Pichau Afrodite      Intel i5-13400F
# 11   PC Gamer Completo Pichau Cicreu VI   AMD Ryzen 3 4350GE
# 12    PC Gamer Completo Pichau Cicreu V   AMD Ryzen 3 4350GE
# 13   PC Gamer Completo Mancer Feácio VI    AMD Ryzen 3 5300G
# ...

# %%
#mudando a linha 35
df.loc[35, 'memória ram'], df.loc[35, 'armazenamento'], df.loc[35, 'placa de video'] = df.loc[35, 'armazenamento'], df.loc[35, 'placa de video'], df.loc[35, 'memória ram']
df
# Out:
#                         nome do produto          processador  \
# 0               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 1               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 2               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 3               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 4             PC Gamer Pichau Sigyn III      Intel i5-10400F
# 5                       PC Gamer Mancer       Intel i3-14100
# 6                       PC Gamer Pichau       Intel i3-12100
# 7               PC Gamer Pichau Crisipo    AMD Ryzen 5 5600X
# 8                PC Gamer Pichau Creteu    AMD Ryzen 5 5600X
# 9                       PC Gamer Pichau      Intel i3-12100F
# 10             PC Gamer Pichau Afrodite      Intel i5-13400F
# 11   PC Gamer Completo Pichau Cicreu VI   AMD Ryzen 3 4350GE
# 12    PC Gamer Completo Pichau Cicreu V   AMD Ryzen 3 4350GE
# 13   PC Gamer Completo Mancer Feácio VI    AMD Ryzen 3 5300G
# ...

# %%
# Tratando Nulos
df['placa de video'] = df['placa de video'].fillna('Sem placa de video')
df
# Out:
#                         nome do produto          processador  \
# 0               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 1               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 2               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 3               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 4             PC Gamer Pichau Sigyn III      Intel i5-10400F
# 5                       PC Gamer Mancer       Intel i3-14100
# 6                       PC Gamer Pichau       Intel i3-12100
# 7               PC Gamer Pichau Crisipo    AMD Ryzen 5 5600X
# 8                PC Gamer Pichau Creteu    AMD Ryzen 5 5600X
# 9                       PC Gamer Pichau      Intel i3-12100F
# 10             PC Gamer Pichau Afrodite      Intel i5-13400F
# 11   PC Gamer Completo Pichau Cicreu VI   AMD Ryzen 3 4350GE
# 12    PC Gamer Completo Pichau Cicreu V   AMD Ryzen 3 4350GE
# 13   PC Gamer Completo Mancer Feácio VI    AMD Ryzen 3 5300G
# ...

# %%
df['armazenamento']=df['armazenamento'].str.replace('+ Cadeira Gamer + Monitor + Kit Per...', ' ').str.replace('+ Monitor + Kit Periféricos', ' ').str.replace('+ Monitor + Kit Periféricos',' ').str.replace(' + Cadeira Gamer',' ')
df
# Out:
#                         nome do produto          processador  \
# 0               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 1               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 2               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 3               Computador Gamer Pichau    AMD Ryzen 5 2400G
# 4             PC Gamer Pichau Sigyn III      Intel i5-10400F
# 5                       PC Gamer Mancer       Intel i3-14100
# 6                       PC Gamer Pichau       Intel i3-12100
# 7               PC Gamer Pichau Crisipo    AMD Ryzen 5 5600X
# 8                PC Gamer Pichau Creteu    AMD Ryzen 5 5600X
# 9                       PC Gamer Pichau      Intel i3-12100F
# 10             PC Gamer Pichau Afrodite      Intel i5-13400F
# 11   PC Gamer Completo Pichau Cicreu VI   AMD Ryzen 3 4350GE
# 12    PC Gamer Completo Pichau Cicreu V   AMD Ryzen 3 4350GE
# 13   PC Gamer Completo Mancer Feácio VI    AMD Ryzen 3 5300G
# ...

# %%
df
# Out:
#                         nome do produto          processador memória ram  \
# 0               Computador Gamer Pichau    AMD Ryzen 5 2400G   16GB DDR4
# 1               Computador Gamer Pichau    AMD Ryzen 5 2400G   16GB DDR4
# 2               Computador Gamer Pichau    AMD Ryzen 5 2400G    8GB DDR4
# 3               Computador Gamer Pichau    AMD Ryzen 5 2400G    8GB DDR4
# 4             PC Gamer Pichau Sigyn III      Intel i5-10400F   16GB DDR4
# 5                       PC Gamer Mancer       Intel i3-14100   16GB DDR4
# 6                       PC Gamer Pichau       Intel i3-12100   16GB DDR4
# 7               PC Gamer Pichau Crisipo    AMD Ryzen 5 5600X   16GB DDR4
# 8                PC Gamer Pichau Creteu    AMD Ryzen 5 5600X   16GB DDR4
# 9                       PC Gamer Pichau      Intel i3-12100F    8GB DDR4
# 10             PC Gamer Pichau Afrodite      Intel i5-13400F   16GB DDR4
# 11   PC Gamer Completo Pichau Cicreu VI   AMD Ryzen 3 4350GE   16GB DDR4
# ...

# %%
df.to_csv('base_pichau_tratada.csv', index=False)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.to_csv('base_pichau_tratada.csv', index=False)
#       2 df
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv('base_pichau_tratada.csv')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv('base_pichau_tratada.csv')
#       2 df
#
# NameError: name 'pd' is not defined

# %%
df['precos']=df['precos'].str.replace('R$',' ')
df
# Out:
#                         nome do produto          processador memória ram  \
# 0               Computador Gamer Pichau    AMD Ryzen 5 2400G   16GB DDR4
# 1               Computador Gamer Pichau    AMD Ryzen 5 2400G   16GB DDR4
# 2               Computador Gamer Pichau    AMD Ryzen 5 2400G    8GB DDR4
# 3               Computador Gamer Pichau    AMD Ryzen 5 2400G    8GB DDR4
# 4             PC Gamer Pichau Sigyn III      Intel i5-10400F   16GB DDR4
# 5                       PC Gamer Mancer       Intel i3-14100   16GB DDR4
# 6                       PC Gamer Pichau       Intel i3-12100   16GB DDR4
# 7               PC Gamer Pichau Crisipo    AMD Ryzen 5 5600X   16GB DDR4
# 8                PC Gamer Pichau Creteu    AMD Ryzen 5 5600X   16GB DDR4
# 9                       PC Gamer Pichau      Intel i3-12100F    8GB DDR4
# 10             PC Gamer Pichau Afrodite      Intel i5-13400F   16GB DDR4
# 11   PC Gamer Completo Pichau Cicreu VI   AMD Ryzen 3 4350GE   16GB DDR4
# ...

# %%
df.to_csv('base_pichau_pronta.csv', index=False)
df
# Out:
#                         nome do produto          processador memória ram  \
# 0               Computador Gamer Pichau    AMD Ryzen 5 2400G   16GB DDR4
# 1               Computador Gamer Pichau    AMD Ryzen 5 2400G   16GB DDR4
# 2               Computador Gamer Pichau    AMD Ryzen 5 2400G    8GB DDR4
# 3               Computador Gamer Pichau    AMD Ryzen 5 2400G    8GB DDR4
# 4             PC Gamer Pichau Sigyn III      Intel i5-10400F   16GB DDR4
# 5                       PC Gamer Mancer       Intel i3-14100   16GB DDR4
# 6                       PC Gamer Pichau       Intel i3-12100   16GB DDR4
# 7               PC Gamer Pichau Crisipo    AMD Ryzen 5 5600X   16GB DDR4
# 8                PC Gamer Pichau Creteu    AMD Ryzen 5 5600X   16GB DDR4
# 9                       PC Gamer Pichau      Intel i3-12100F    8GB DDR4
# 10             PC Gamer Pichau Afrodite      Intel i5-13400F   16GB DDR4
# 11   PC Gamer Completo Pichau Cicreu VI   AMD Ryzen 3 4350GE   16GB DDR4
# ...

# %%
df = pd.read_csv('base_pichau_pronta.csv')
df
# Out:
#                         nome do produto          processador memória ram  \
# 0               Computador Gamer Pichau    AMD Ryzen 5 2400G   16GB DDR4
# 1               Computador Gamer Pichau    AMD Ryzen 5 2400G   16GB DDR4
# 2               Computador Gamer Pichau    AMD Ryzen 5 2400G    8GB DDR4
# 3               Computador Gamer Pichau    AMD Ryzen 5 2400G    8GB DDR4
# 4             PC Gamer Pichau Sigyn III      Intel i5-10400F   16GB DDR4
# 5                       PC Gamer Mancer       Intel i3-14100   16GB DDR4
# 6                       PC Gamer Pichau       Intel i3-12100   16GB DDR4
# 7               PC Gamer Pichau Crisipo    AMD Ryzen 5 5600X   16GB DDR4
# 8                PC Gamer Pichau Creteu    AMD Ryzen 5 5600X   16GB DDR4
# 9                       PC Gamer Pichau      Intel i3-12100F    8GB DDR4
# 10             PC Gamer Pichau Afrodite      Intel i5-13400F   16GB DDR4
# 11   PC Gamer Completo Pichau Cicreu VI   AMD Ryzen 3 4350GE   16GB DDR4
# ...

# %%
print(df['precos'].unique())
# Out:
# ['  1.520,00' '  1.450,00' '  1.299,99' '  1.259,99' '  2.648,31'
#  '  2.489,96' '  2.199,97' '  4.872,55' '  6.634,08' '  2.459,98'
#  '  3.799,86' '  2.589,99' '  2.089,98' '  2.889,98' '  2.339,98'
#  '  1.539,99' '  4.299,98' '  1.449,99' '  1.389,95' '  1.899,98'
#  '  2.569,98' '  1.879,99' '  1.909,96' '  2.219,97' '  1.749,99'
#  '  1.936,36' '  1.629,98' '  2.099,98' '  1.799,98' '  1.866,25'
#  '  1.699,98' '  3.859,96' '  1.429,99' '  4.699,96']

# %%
df['precos'] = df['precos'].str.strip()

# %%
print(df['precos'].unique())
# Out:
# ['1.520,00' '1.450,00' '1.299,99' '1.259,99' '2.648,31' '2.489,96'
#  '2.199,97' '4.872,55' '6.634,08' '2.459,98' '3.799,86' '2.589,99'
#  '2.089,98' '2.889,98' '2.339,98' '1.539,99' '4.299,98' '1.449,99'
#  '1.389,95' '1.899,98' '2.569,98' '1.879,99' '1.909,96' '2.219,97'
#  '1.749,99' '1.936,36' '1.629,98' '2.099,98' '1.799,98' '1.866,25'
#  '1.699,98' '3.859,96' '1.429,99' '4.699,96']

# %%
# 3. Remover pontos de milhares e substituir vírgulas por pontos para decimais
df['precos'] = df['precos'].str.replace(r'\.', '', regex=True)  # Remove separadores de milhares
df['precos'] = df['precos'].str.replace(r',', '.', regex=True)  # Substitui vírgula por ponto decimal

# %%
df
# Out:
#                         nome do produto          processador memória ram  \
# 0               Computador Gamer Pichau    AMD Ryzen 5 2400G   16GB DDR4
# 1               Computador Gamer Pichau    AMD Ryzen 5 2400G   16GB DDR4
# 2               Computador Gamer Pichau    AMD Ryzen 5 2400G    8GB DDR4
# 3               Computador Gamer Pichau    AMD Ryzen 5 2400G    8GB DDR4
# 4             PC Gamer Pichau Sigyn III      Intel i5-10400F   16GB DDR4
# 5                       PC Gamer Mancer       Intel i3-14100   16GB DDR4
# 6                       PC Gamer Pichau       Intel i3-12100   16GB DDR4
# 7               PC Gamer Pichau Crisipo    AMD Ryzen 5 5600X   16GB DDR4
# 8                PC Gamer Pichau Creteu    AMD Ryzen 5 5600X   16GB DDR4
# 9                       PC Gamer Pichau      Intel i3-12100F    8GB DDR4
# 10             PC Gamer Pichau Afrodite      Intel i5-13400F   16GB DDR4
# 11   PC Gamer Completo Pichau Cicreu VI   AMD Ryzen 3 4350GE   16GB DDR4
# ...

# %%
df.to_csv('base_pichau_pronta.csv', index=False)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.to_csv('base_pichau_pronta.csv', index=False)
#       2 df
#
# NameError: name 'df' is not defined
